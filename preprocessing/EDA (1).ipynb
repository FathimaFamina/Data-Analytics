# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt            
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv(r'C:\Users\USER\Downloads\marksheet.csv')
df.head(5)
# Out:
#    id      Name  Gender  Age Section  Science  English  History  Maths
# 0   1     Merle  Female   13       C        5       83       19     39
# 1   2     Valma  Female   14       C       48       83       79     95
# 2   3      Jone    Male   14       A       17       87       16     50
# 3   4       Rae  Female   15       A       16       59       18     64
# 4   5  Charmine  Female   14       A       93       93       83     40

# %%
df.tail(5)
# Out:
#    id       Name  Gender  Age Section  Science  English  History  Maths
# 5   6      Hanan    Male   14       A       60       36       86     87
# 6   7     Adrian    Male   13       C       19        8       76     75
# 7   8      Livia    Male   13       C       95       65       25     91
# 8   9     Richie  Female   15       B       14       83        9     90
# 9  10  Ekaterina  Female   15       B       17       36       45     27

# %%
df.dtypes
# Out:
# id          int64
# Name       object
# Gender     object
# Age         int64
# Section    object
# Science     int64
# English     int64
# History     int64
# Maths       int64
# dtype: object

# %%
df.count()
# Out:
# id         10
# Name       10
# Gender     10
# Age        10
# Section    10
# Science    10
# English    10
# History    10
# Maths      10
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#    id      Name  Gender  Age Section  Science  English  History  Maths
# 0   1     Merle  Female   13       C        5       83       19     39
# 1   2     Valma  Female   14       C       48       83       79     95
# 2   3      Jone    Male   14       A       17       87       16     50
# 3   4       Rae  Female   15       A       16       59       18     64
# 4   5  Charmine  Female   14       A       93       93       83     40

# %%
sns.boxplot(x=df['Science'])
# Out:
# <Axes: xlabel='Science'>

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=df['English'])
# Out:
# <Axes: xlabel='English'>

# %%
Q1 = np.percentile(df['Age'],25)
Q1
# Out:
# 13.25

# %%
Q3 = np.percentile(df['History'],75)
Q3
# Out:
# 78.25

# %%
IQR = Q3 - Q1
IQR
# Out:
# 65.0

# %%
low_limit = Q1-1.5*IQR
low_limit
# Out:
# -84.25

# %%
up_limit = Q3+1.5*IQR
up_limit
# Out:
# 175.75

# %%
df['Age']
# Out:
# 0    13
# 1    14
# 2    14
# 3    15
# 4    14
# 5    14
# 6    13
# 7    13
# 8    15
# 9    15
# Name: Age, dtype: int64

# %%
df['Age'].value_counts().plot(kind='bar', figsize=(10,5))

plt.title("progress card")
plt.ylabel('Maths')
plt.xlabel('Age');

# %%
# plt.figure(figsize=(10,5))
# c= df.corr()
# sns.heatmap(c,cmap="BrBG",annot=True)
# c

# Identify and handle non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=[np.number]).columns
df_numeric = df.drop(non_numeric_cols, axis=1)  # Drop non-numeric columns

# Alternatively, encode categorical columns if they are meaningful
# Example: Using pandas get_dummies for one-hot encoding
df_encoded = pd.get_dummies(df)  # Convert categorical variables into dummy/indicator variables

# Calculate correlation matrix on the processed DataFrame
c = df_encoded.corr()

# Plot heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(c, cmap="BrBG", annot=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Age'], df['History'])
ax.set_xlabel('Age')
ax.set_ylabel('History')
plt.show()

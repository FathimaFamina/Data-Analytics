# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\USER\Downloads\drinks.csv")
data
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             1  Afghanistan            0.0              NaN            0.0
# 1             2      Albania           89.0            132.0           54.0
# 2             3      Algeria           25.0              0.0           14.0
# 3             4      Andorra          245.0            138.0          312.0
# 4             5       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         189    Venezuela          333.0            100.0            3.0
# 189         190      Vietnam          111.0              2.0            1.0
# 190         191        Yemen            6.0              NaN            NaN
# 191         192       Zambia           32.0             19.0            4.0
# 192         193     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
data.shape
# Out:
# (193, 7)

# %%
data=data.drop('Unnamed: 0', axis=1)
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              NaN            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             NaN           Asia
# 1                             4.9         Europe
# ...

# %%
data.shape
# Out:
# (193, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 182 non-null    float64
#  2   spirit_servings               176 non-null    float64
#  3   wine_servings                 169 non-null    float64
#  4   total_litres_of_pure_alcohol  190 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 9.2+ KB

# %%
data.isna().sum()
# Out:
# country                          0
# beer_servings                   11
# spirit_servings                 17
# wine_servings                   24
# total_litres_of_pure_alcohol     3
# continent                        0
# dtype: int64

# %%
data['beer_servings'].plot(kind='box')
# Out:
# <Axes: >

# %%
# no outliers use mean
data['beer_servings'].mean()
# Out:
# 112.57692307692308

# %%
data['beer_servings']=data['beer_servings'].fillna(data['beer_servings'].mean())
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              NaN            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             NaN           Asia
# 1                             4.9         Europe
# ...

# %%
data['beer_servings'].isna().sum()
# Out:
# 0

# %%
data['total_litres_of_pure_alcohol'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['total_litres_of_pure_alcohol'].mean()
# Out:
# 4.791578947368421

# %%
data['total_litres_of_pure_alcohol']=data['total_litres_of_pure_alcohol'].fillna(data['total_litres_of_pure_alcohol'].mean())
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              NaN            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              NaN            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                        4.791579           Asia
# 1                        4.900000         Europe
# ...

# %%
data['total_litres_of_pure_alcohol'].isna().sum()
# Out:
# 0

# %%
data['spirit_servings'].plot(kind='box')
# Out:
# <Axes: >

# %%
#with outliers use median
data['spirit_servings'].median()
# Out:
# 68.5

# %%
data['spirit_servings']=data['spirit_servings'].fillna(data['spirit_servings'].median())
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0             68.5            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0             68.5            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                        4.791579           Asia
# 1                        4.900000         Europe
# ...

# %%
data['spirit_servings'].isna().sum()
# Out:
# 0

# %%
#to remove outliers

Q1 = data['spirit_servings'].quantile(0.25)
Q1
# Out:
# 18.0

# %%
# Q1 = np.percentile(data['spirit_servings'],25)
# Q1

# %%
Q3 = data['spirit_servings'].quantile(0.75)
Q3
# Out:
# 128.0

# %%
Q2 = data['spirit_servings'].median()
Q2
# Out:
# 68.5

# %%
IQR=Q3-Q1
IQR
# Out:
# 110.0

# %%
# Define inner fences
lower_bound = Q1 - 1.5 * IQR
lower_bound
# Out:
# -147.0

# %%
upper_bound = Q3 + 1.5 * IQR
upper_bound
# Out:
# 293.0

# %%
# Identify outliers
outliers = data[(data['spirit_servings'] < lower_bound) | (data['spirit_servings'] > upper_bound)]
outliers
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus          142.0            373.0           42.0
# 68              Grenada          199.0            438.0           28.0
# 72               Guyana           93.0            302.0            1.0
# 73                Haiti            1.0            326.0            1.0
# 141  Russian Federation          247.0            326.0           73.0
# 144           St. Lucia          171.0            315.0           71.0
#
#      total_litres_of_pure_alcohol      continent
# 15                           14.4         Europe
# 68                           11.9  North America
# 72                            7.1  South America
# 73                            5.9  North America
# 141                          11.5           Asia
# 144                          10.1  North America

# %%
# Handle outliers (e.g., remove them)
cleaned_data = data[(data['spirit_servings'] >= lower_bound) & (data['spirit_servings'] <= upper_bound)]
cleaned_data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0             68.5            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0             68.5            NaN
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                        4.791579           Asia
# 1                        4.900000         Europe
# ...

# %%
cleaned_data['spirit_servings'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['wine_servings'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['wine_servings'].mean()
# Out:
# 56.47337278106509

# %%
data['wine_servings']=data['wine_servings'].fillna(data['wine_servings'].mean())
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0             68.5       0.000000
# 1        Albania           89.0            132.0      54.000000
# 2        Algeria           25.0              0.0      14.000000
# 3        Andorra          245.0            138.0     312.000000
# 4         Angola          217.0             57.0      45.000000
# ..           ...            ...              ...            ...
# 188    Venezuela          333.0            100.0       3.000000
# 189      Vietnam          111.0              2.0       1.000000
# 190        Yemen            6.0             68.5      56.473373
# 191       Zambia           32.0             19.0       4.000000
# 192     Zimbabwe           64.0             18.0       4.000000
#
#      total_litres_of_pure_alcohol      continent
# 0                        4.791579           Asia
# 1                        4.900000         Europe
# ...

# %%
data['wine_servings'].isna().sum()
# Out:
# 0

# %%
pd.options.display.max_rows = 9999
data
# Out:
#                           country  beer_servings  spirit_servings  \
# 0                     Afghanistan       0.000000             68.5
# 1                         Albania      89.000000            132.0
# 2                         Algeria      25.000000              0.0
# 3                         Andorra     245.000000            138.0
# 4                          Angola     217.000000             57.0
# 5               Antigua & Barbuda     102.000000            128.0
# 6                       Argentina     193.000000             25.0
# 7                         Armenia      21.000000            179.0
# 8                       Australia     261.000000             72.0
# 9                         Austria     279.000000             75.0
# 10                     Azerbaijan      21.000000             46.0
# 11                        Bahamas     122.000000            176.0
# 12                        Bahrain      42.000000             63.0
# ...

# %%
Q1 = data['wine_servings'].quantile(0.25)
Q1
# Out:
# 4.0

# %%
Q3 = data['wine_servings'].quantile(0.75)
Q3
# Out:
# 59.0

# %%
# Calculate IQR
IQR = Q3 - Q1
IQR
# Out:
# 55.0

# %%
# Define upper and lower bounds for outliers
lower_bound = Q1 - 1.5 * IQR
lower_bound
# Out:
# -78.5

# %%
upper_bound = Q3 + 1.5 * IQR
upper_bound
# Out:
# 141.5

# %%
# Identify outliers
# outliers_W = data[(data['wine_servings'] < lower_bound) | (data['wine_servings'] > upper_bound)]
# outliers_W

# %%
outliers_W.shape
# Out:
# (26, 6)

# %%
# Handle outliers (e.g., remove them)
cleaned_data2 = data[(data['spirit_servings'] >= lower_bound) & (data['spirit_servings'] <= upper_bound)]

cleaned_data2
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 0                 Afghanistan       0.000000             68.5       0.000000
# 1                     Albania      89.000000            132.0      54.000000
# 2                     Algeria      25.000000              0.0      14.000000
# 4                      Angola     217.000000             57.0      45.000000
# 5           Antigua & Barbuda     102.000000            128.0      45.000000
# 6                   Argentina     193.000000             25.0     221.000000
# 8                   Australia     261.000000             72.0     212.000000
# 9                     Austria     279.000000             75.0     191.000000
# 10                 Azerbaijan      21.000000             46.0       5.000000
# 12                    Bahrain      42.000000             63.0       7.000000
# 13                 Bangladesh       0.000000              0.0       0.000000
# ...

# %%
cleaned_data2['wine_servings'].plot(kind='box')
# Out:
# <Axes: >

# %%
Q1 = cleaned_data2['wine_servings'].quantile(0.25)
Q1
# Out:
# 3.0

# %%
Q3 = cleaned_data2['wine_servings'].quantile(0.75)
Q3
# Out:
# 56.47337278106509

# %%
# Calculate the interquartile range (IQR)
# Q1 = cleaned_data2['wine_servings'].quantile(0.25)
# Q3 = cleaned_data2['wine_servings'].quantile(0.75)
# IQR = Q3 - Q1

# Define the lower and upper bounds
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
cleaned_data_no_outliers = cleaned_data2[(cleaned_data2['wine_servings'] >= lower_bound) & (cleaned_data2['wine_servings'] <= upper_bound)]

# Plot box plot again to verify
cleaned_data_no_outliers['wine_servings'].plot(kind='box')
# Out:
# <Axes: >

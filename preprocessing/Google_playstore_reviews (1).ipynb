# %% [markdown]
# pip install google-play-scraper

# %%
# !pip install google-play-scraper

# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4
# Requirement already satisfied: google-play-scraper in c:\users\user\anaconda3\lib\site-packages (1.2.4)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import app

result = app(
    'com.snapchat.android',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)

# %%
print(result)
# Out:
# {'title': 'Snapchat', 'description': "Snapchat is a fast and fun way to share the moment with your friends and family 👻\r\n\r\nSNAP \r\n• Snapchat opens right to the Camera — just tap to take a photo, or press and hold for video.\r\n• Express yourself with Lenses, Filters, Bitmoji and more! \r\n• Try out new Lenses daily created by the Snapchat community!\r\n\r\nCHAT \r\n• Stay in touch with friends through live messaging, or share your day with Group Stories.\r\n• Video Chat with up to 16 friends at once — you can even use Lenses and Filters when chatting!\r\n• Express yourself with Friendmojis — exclusive Bitmoji made just for you and a friend.\r\n\r\nSTORIES\r\n• Watch friends' Stories to see their day unfold.\r\n• See Stories from the Snapchat community that are based on your interests.\r\n• Discover breaking news and exclusive Original Shows.\r\n\r\nSPOTLIGHT\r\n• Spotlight showcases the best of Snapchat!\r\n• Submit your own Snaps or sit back, relax, and watch.\r\n• Pick your favorites and share them with friends.\r\n\r\nMAP \r\n• Share your location with your best friends or go off the grid with Ghost Mode.\r\n• See what your friends are up to on your most personal map when they share their location with you. \r\n• Explore live Stories from the community nearby or across the world!\r\n\r\nMEMORIES \r\n• Save unlimited photos and videos of all your favorite moments.\r\n• Edit and send old moments to friends or save them to your Camera Roll.\r\n• Create Stories from your favorite Memories to share with friends and family.\r\n\r\nFRIENDSHIP PROFILE \r\n• Every friendship has its own special profile to see the moments you’ve saved together.\r\n• Discover new things you have in common with Charms — see how long you’ve been friends, your astrological compatibility, your Bitmoji fashion sense, and more!\r\n• Friendship Profiles are just between you and a friend, so you can bond over what makes your friendship special.\r\n\r\nHappy Snapping!\r\n\r\n• • •\r\n\r\nPlease note: Snapchatters can always capture or save your messages by taking a screenshot, using a camera, or otherwise. Be mindful of what you Snap!\r\n\r\nFor a full description of our privacy practices, please see our Privacy Center.", 'descriptionHTML': 'Snapchat is a fast and fun way to share the moment with your friends and family 👻<br><br>SNAP <br>• Snapchat opens right to the Camera — just tap to take a photo, or press and hold for video.<br>• Express yourself with Lenses, Filters, Bitmoji and more! <br>• Try out new Lenses daily created by the Snapchat community!<br><br>CHAT <br>• Stay in touch with friends through live messaging, or share your day with Group Stories.<br>• Video Chat with up to 16 friends at once — you can even use Lenses and Filters when chatting!<br>• Express yourself with Friendmojis — exclusive Bitmoji made just for you and a friend.<br><br>STORIES<br>• Watch friends&#39; Stories to see their day unfold.<br>• See Stories from the Snapchat community that are based on your interests.<br>• Discover breaking news and exclusive Original Shows.<br><br>SPOTLIGHT<br>• Spotlight showcases the best of Snapchat!<br>• Submit your own Snaps or sit back, relax, and watch.<br>• Pick your favorites and share them with friends.<br><br>MAP <br>• Share your location with your best friends or go off the grid with Ghost Mode.<br>• See what your friends are up to on your most personal map when they share their location with you. <br>• Explore live Stories from the community nearby or across the world!<br><br>MEMORIES <br>• Save unlimited photos and videos of all your favorite moments.<br>• Edit and send old moments to friends or save them to your Camera Roll.<br>• Create Stories from your favorite Memories to share with friends and family.<br><br>FRIENDSHIP PROFILE <br>• Every friendship has its own special profile to see the moments you’ve saved together.<br>• Discover new things you have in common with Charms — see how long you’ve been friends, your astrologica ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.snapchat.android',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=100, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.snapchat.android',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
print(result)
# Out:
# [{'reviewId': 'eb5e83c6-dc90-4d06-bb06-e5266c40852f', 'userName': 'Aaqeelah Lathiff', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVBkdz0BhPHix1CFcBD87Bm7cAoAGiu4EhkcQpN9jAcJTE', 'content': "An amazing app with updates and everything although it would be nicer if you could change your background wallpaper for your chats without having to buy the premium package but I'm giving it 5 stars anyway hopefully they listen to this review 😀", 'score': 5, 'thumbsUpCount': 4, 'reviewCreatedVersion': '12.64.0.42', 'at': datetime.datetime(2023, 12, 16, 16, 19, 2), 'replyContent': None, 'repliedAt': None, 'appVersion': '12.64.0.42'}, {'reviewId': '6487fdbf-dd91-4b3c-8667-27952829d78e', 'userName': 'PAYAL YADAV', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWIBmnWA8OhpDCQU-FCDUAc9AK8ywOKmcTvN7e3R4Af3_Q', 'content': "Snapchat Is good for taking snaps using fliters... But for chat box you should add feature like locking chat page, so that anyone who borrow another phone can't access in chat box.", 'score': 5, 'thumbsUpCount': 4, 'reviewCreatedVersion': '12.63.0.55', 'at': datetime.datetime(2023, 12, 8, 20, 48, 49), 'replyContent': None, 'repliedAt': None, 'appVersion': '12.63.0.55'}, {'reviewId': '0b808638-8d94-407a-87da-522e13eddfac', 'userName': 'Harini Pogulakonda', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIaaqTvRgh4cin2vB1c1409vAs9WyjWYtZ6vjudofgh=mo', 'content': 'Few filters are more creative , Ai is an amazing feature ,people can make friends according to their taste , so secured , I m so happy to use this app since a couple of years .', 'score': 5, 'thumbsUpCount': 3, 'reviewCreatedVersion': '12.64.0.42', 'at': datetime.datetime(2023, 12, 17, 12, 19, 43), 'replyContent': None, 'repliedAt': None, 'appVersion': '12.64.0.42'}, {'reviewId': '65a770c8-8a70-48ca-b9ae-a4b0ad788ea9', 'userName': 'Marcia Walkine', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUjef6i_qCt59DAl0ZqW-RW7afx-h-6BhYapg0q7evCv14', 'content': 'this is great and all love the filters but I\'m sure it is not supposed say " Snapchat was unable to open the camera . you may need to restart the application or your device', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '12.64.0.42', 'at': datetime.datetime(2023, 12, 21, 9, 53, 23), 'replyContent': None, 'repliedAt': None, 'appVersion': '12.64.0.42'}, {'reviewId': 'a09c64fe-c74d-4abc-ae14-e692f5ca12bc', 'userName': 'Hevi Q.', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWJhUtvgNV1IHe9wEIJm6Unx2TcSb1ubdy05yWBVzGw1jI', 'content': "Snapchat is the bAmb, it's the greatest app ever! I love it so much, it changes how we feel in an instant. For instance we learn to love one another.", 'score': 5, 'thumbsUpCount': 9, 'reviewCreatedVersion': '12.63.0.55', 'at': datetime.datetime(2023, 12, 9, 15, 0, 35), 'replyContent': None, 'repliedAt': None, 'appVersion': '12.63.0.55'}, {'reviewId': '0e77c1ae-d47b-4257-86e6-1f83c3028cfa', 'userName': 'Ava Lawson', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUBRjOfYXGcYkRS_O839ITtOCRZfQMYRnTkhDOAjllIvXo', 'content': 'Great app the only thing is that there not that much variety in snap map pets and not that many cozy clothes or slippers but overall very great app.', 'score': 5, 'thumbsUpCount': 10, 'reviewCreatedVersion': '12.63.0.55', 'at': datetime.datetime(2023, 12, 7, 4, 40, 29), 'replyContent': None, 'repliedAt': None, 'appVersion': '12.63.0.55'}, {'reviewId': '2c7ec16b-956b-4de7-a26e-f31d3a69738b', 'userName': 'rashmita Patnaik', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLeLPQa0ZT-jcpIH9mfs7DQ_30_713wXJRMA4E_dSDs1MU=mo', 'content': 'I like this app very much because if I have to send any photo I have to go in WhatsApp but now I can easily send it .............. I love this app very muchhhhhhhhhhhhhh... It makes my heart is true because my friend and family also send me which I can only seen I love this app', 'score': 5, 'thumbsUpCount': 1, 'reviewCreatedVersion': '12.63.0.55 ...

# %% [markdown]
# from google_play_scraper import Sort, reviews_all
#
# result = reviews_all(
#     'com.facebook.orca',
#     sleep_milliseconds=0, # defaults to 0
#     lang='en', # defaults to 'en'
#     country='us', # defaults to 'us'
#     sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
#     filter_score_with=5 # defaults to None(means all score)
# )

# %% [markdown]
# print(result)

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.facebook.orca',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.facebook.orca',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
print(result)
# Out:
# [{'reviewId': '0fd71b6d-acda-4dc3-bec1-90c87d68629b', 'userName': 'Colleen Jimmie', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKhX6Vx9Fg8zpnXBlDgo-5zJSlSno8PvJOfVStVtK6x=mo', 'content': 'Good Good Good Good Good', 'score': 5, 'thumbsUpCount': 3, 'reviewCreatedVersion': None, 'at': datetime.datetime(2023, 12, 15, 19, 9, 15), 'replyContent': None, 'repliedAt': None, 'appVersion': None}, {'reviewId': '675b149b-e52b-4f63-ae52-2cfd32011cef', 'userName': 'Babashafqat Babashafqat', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX0A8fbm4V-r-HdkaHui1bqyy9qLJOk3nBsfzwuwlvPLA', 'content': 'Excellent', 'score': 5, 'thumbsUpCount': 2, 'reviewCreatedVersion': '436.0.0.45.111', 'at': datetime.datetime(2023, 12, 15, 17, 9, 53), 'replyContent': None, 'repliedAt': None, 'appVersion': '436.0.0.45.111'}, {'reviewId': 'a2bb6df6-e28f-4eeb-8f38-2a4825264d14', 'userName': 'Michael Cañete', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU_xdiBUN3o0r5KdPJpAc1a0EH7Ca2Re253wYE4KHVVsw', 'content': 'In this is a apps is very good to effect on my phone', 'score': 5, 'thumbsUpCount': 6, 'reviewCreatedVersion': None, 'at': datetime.datetime(2023, 12, 15, 2, 27, 54), 'replyContent': None, 'repliedAt': None, 'appVersion': None}]

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])


df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))



df_busu.head()
# Out:
#                                reviewId            userName  \
# 0  eb5e83c6-dc90-4d06-bb06-e5266c40852f    Aaqeelah Lathiff
# 1  6487fdbf-dd91-4b3c-8667-27952829d78e         PAYAL YADAV
# 2  0b808638-8d94-407a-87da-522e13eddfac  Harini Pogulakonda
# 3  65a770c8-8a70-48ca-b9ae-a4b0ad788ea9      Marcia Walkine
# 4  a09c64fe-c74d-4abc-ae14-e692f5ca12bc             Hevi Q.
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  An amazing app with updates and everything alt...      5              4
# 1  Snapchat Is good for taking snaps using fliter...      5              4
# 2  Few filters are more creative , Ai is an amazi...      5              3
# 3  this is great and all love the filters but I'm...      5              0
# 4  Snapchat is the bAmb, it's the greatest app ev...      5              9
#
#   reviewCreatedVersion                  at replyContent repliedAt  appVersion
# 0           12.64.0.42 2023-12-16 16:19:02         None      None  12.64.0.42
# 1           12.63.0.55 2023-12-08 20:48:49         None      None  12.63.0.55
# 2           12.64.0.42 2023-12-17 12:19:43         None      None  12.64.0.42
# 3           12.64.0.42 2023-12-21 09:53:23         None      None  12.64.0.42
# 4           12.63.0.55 2023-12-09 15:00:35         None      None  12.63.0.55

# %%
from IPython.display import HTML
import base64
def create_download_link( data, title = "Download CSV file", filename = "df_busu.csv"):
    csv = df_busu.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(df_busu)
# Out:
# <a download="df_busu.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
